# %% [markdown]
# # `Import the main Libraries`

# %%
## Major Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings

warnings.filterwarnings("ignore")
# %load_ext nb_black

# %%
# Path dataset
path_versoin_1 = r"D:\Software_Courses\Coding\Data Science Project\life_expectancy\data\processed/data_version_1.pkl"

# %%
# Read data and print head
df = pd.read_pickle(path_versoin_1)
df.head()
# Out:
#        country  year      status  life_expectancy  adult_mortality
# 0  Afghanistan  2015  Developing             65.0            263.0  \
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant_deaths  alcohol  percentage_expenditure  hepatitis_b    measles
# 0       2.398311     0.01                   12.20         65.0  10.790505  \
# 1       2.398311     0.01                   12.00         62.0  35.662068
# 2       2.398311     0.01                   11.59         64.0  35.662068
# 3       2.398311     0.01                   11.67         67.0  10.790505
# 4       2.398311     0.01                   11.17         68.0  10.790505
#
#    ...  polio  total_expenditure  diphtheria  hiv/aids         gdp
# ...

# %% [markdown]
# # `Univariate Analysis`

# %%
# Get summery statistics for the numerical column
df.describe().T.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_0f6de_row0_col0, #T_0f6de_row0_col3, #T_0f6de_row1_col0, #T_0f6de_row2_col0, #T_0f6de_row3_col0, #T_0f6de_row7_col0, #T_0f6de_row8_col0, #T_0f6de_row9_col0, #T_0f6de_row13_col0, #T_0f6de_row15_col1, #T_0f6de_row15_col2, #T_0f6de_row15_col4, #T_0f6de_row15_col5, #T_0f6de_row15_col6, #T_0f6de_row15_col7, #T_0f6de_row16_col0, #T_0f6de_row17_col0, #T_0f6de_row18_col0, #T_0f6de_row19_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# ...

# %%
# distplot Distribution of Numerical(continues) Variables in Dataset
col_discrete = ["schooling", "year"]
plt.figure(figsize=(10, 20))
count = 0
for num, name in enumerate(df.select_dtypes(exclude="object")):
    if name in (col_discrete):
        continue
    else:
        plt.subplot(7, 3, count + 1)
        sns.distplot(df[name])
        plt.title(name)
        plt.tight_layout()
        count += 1
plt.show()

# %%
## Countplot of categorical Variables in Dataset
# Set the figure size
plt.figure(figsize=(20, 200))

# Create the count plot
for i, name in enumerate(["status", "schooling"]):
    plt.subplot(24, 2, i + 1)
    sns.countplot(x=df[name], order=df[name].value_counts().index, palette="rocket")

    # Set labels and title
    plt.title(f"Countplot Distribution of {name}", color="red", fontsize=25)
    plt.xlabel(name, color="red", fontsize=25)
    plt.ylabel("Count", color="red", fontsize=25)

# Display the plot
plt.show()

# %% [markdown]
# # `Bivariate Analysis`

# %% [markdown]
# # `1. How does life expectancy vary across different countries and years?`

# %%
# How does life expectancy vary across different years?
# Set the figure size
plt.figure(figsize=(8, 4))

# Create the line plot
sns.lineplot(data=df, x="year", y="life_expectancy")

# Set labels and title
plt.xlabel("Year", color="red")
plt.ylabel("Life Expectancy", color="red")
plt.title("Life Expectancy Variation Across  Years", color="red")

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
# What is the country that has the highest average life expectancy?
df[df.life_expectancy == df.life_expectancy.max()]
# Out:
#        country  year      status  life_expectancy  adult_mortality
# 241    Belgium  2014   Developed             89.0             76.0  \
# 937     France  2008  Developing             89.0             88.0
# 938     France  2007  Developing             89.0             89.0
# 995    Germany  2014   Developed             89.0             69.0
# 1293     Italy  2004   Developed             89.0             66.0
# 2056  Portugal  2014   Developed             89.0             78.0
# 2433     Spain  2007   Developed             89.0             72.0
# 2513    Sweden  2007   Developed             89.0             63.0
#
#       infant_deaths  alcohol  percentage_expenditure  hepatitis_b    measles
# 241             0.0    12.60                   15.10         98.0  11.504501  \
# 937             3.0    11.90                   15.42         47.0  35.662068
# 938             3.0    12.20                   15.54         42.0  39.000000
# ...

# %%
##  How does life expectancy vary across different the country that has the highest average life expectancy and years?
# Set the figure size
plt.figure(figsize=(13, 6))

# Create the line plot
sns.lineplot(data=df, x="year", y="life_expectancy",hue=df[df['country'].isin(df[df.life_expectancy == df.life_expectancy.max()]['country'].tolist())]['country'])

# Set labels and title
plt.xlabel("Year", color="red")
plt.ylabel("Life Expectancy", color="red")
plt.title("Life Expectancy Variation Across the country that has the highest average life expectancy and Years", color="red")

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
# Which country has the lowest life expectancy?
df[df.life_expectancy == df.life_expectancy.min()]
# Out:
#      country  year      status  life_expectancy  adult_mortality
# 1581  Malawi  2004  Developing             45.1       149.655434  \
#
#       infant_deaths  alcohol  percentage_expenditure  hepatitis_b    measles
# 1581        4.22666     1.11                    21.2         89.0  10.790505  \
#
#       ...  polio  total_expenditure  diphtheria  hiv/aids         gdp
# 1581  ...   94.0               7.82        89.0  0.101958  274.225629  \
#
#       population  thinness__1-19_years  thinness_5-9_years
# 1581   1267638.0                   7.5                 7.4  \
#
#       income_composition_of_resources  schooling
# 1581                            0.366       10.0
#
# [1 rows x 22 columns]

# %%
##  How does life expectancy vary across different the country that has the lowest average life expectancy and years?
# Set the figure size
plt.figure(figsize=(8, 4))

# Create the line plot
sns.lineplot(data=df, x="year", y="life_expectancy",hue=df[df['country'].isin(df[df.life_expectancy == df.life_expectancy.min()]['country'].tolist())]['country'])

# Set labels and title
plt.xlabel("Year", color="red")
plt.ylabel("Life Expectancy", color="red")
plt.title("Life Expectancy Variation Across the country that has the lowest average life expectancy and Years", color="red")

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# # `2. Is there any correlation between adult mortality rate and life expectancy?`

# %%
# Correlation between adult mortality rate and life expectancy
df[["life_expectancy", "adult_mortality"]].corr()
# Out:
#                  life_expectancy  adult_mortality
# life_expectancy         1.000000        -0.506239
# adult_mortality        -0.506239         1.000000

# %%
#Correlation between adult mortality rate and life expectancy
# Set the figure size
plt.figure(figsize=(8, 4))

# Create the line plot
sns.scatterplot(data=df, x="life_expectancy", y="adult_mortality")

# Set labels and title
plt.ylabel("Year", color="red")
plt.xlabel("Life Expectancy", color="red")
plt.title("Correlation between adult mortality rate and life expectancy", color="red")

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# # `3. How does the percentage of infant deaths vary by country and year?`

# %%
# How does life expectancy vary across different years?
# Set the figure size
plt.figure(figsize=(8, 4))

# Create the line plot
sns.lineplot(data=df, x="year", y="infant_deaths")

# Set labels and title
plt.xlabel("Year", color="red")
plt.ylabel("infant_deaths", color="red")
plt.title("Infant deaths Variation Across  Years", color="red")

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
# What is the country that has the highest average Infant deaths?
df[df.infant_deaths == df.infant_deaths.max()].country.value_counts()
# Out:
# country
# Tajikistan              11
# Papua New Guinea         6
# Argentina                4
# Liberia                  3
# Guatemala                2
# Peru                     2
# Syrian Arab Republic     2
# Thailand                 2
# Cambodia                 1
# Colombia                 1
# Name: count, dtype: int64

# %% [markdown]
# **`(Insights)`<br>**
# **`Tajikistan has the highest infant deaths rate over the years from the period between 2005 to 2015.`**

# %% [markdown]
# **`(3.1)  How does the average life expectancy vary across different years in Tajikistan , which has  the highest infant deaths rate over the years from the period between 2005 to 2015.`**

# %%
# Set the figure size
plt.figure(figsize=(6, 3))

# Create the line plot
sns.lineplot(df[df.country == "Tajikistan"], y="life_expectancy", x="year")

# Set labels and title
plt.xlabel("Year", color="red")
plt.ylabel("life_expectancy", color="red")
plt.title(
    "How does the average life expectancy vary across different years in Tajikistan",
    color="red",
)

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
##  How does the percentage of infant deaths vary by country and year?
# Set the figure size
plt.figure(figsize=(10, 4))

# Create the line plot
sns.lineplot(data=df, x="year", y="infant_deaths",hue=df[df['country'].isin(df[df.infant_deaths == df.infant_deaths.max()]["country"].value_counts().reset_index().head(5)['country'].tolist())]['country'])

# Set labels and title
plt.xlabel("Year", color="red")
plt.ylabel("Infant Deaths", color="red")
plt.title("How does the percentage of infant deaths vary by country and year", color="red")

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# # `4. What is the trend of alcohol consumption over the years?`

# %%
# Set the figure size
plt.figure(figsize=(10, 4))

# Calculate the mean of the "alcohol" column
alcohol_mean = df.groupby("year")["alcohol"].mean()

# Line plot and bar plot
plt.plot(alcohol_mean.index, alcohol_mean.values,marker='o',color='red',markersize=5)
plt.bar(alcohol_mean.index, alcohol_mean.values)

# Set labels and title
plt.xlabel("Year",color="red")
plt.ylabel("Alcohol",color="red")
plt.title("Trend of alcohol consumption over the years",color="green")

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# **`(4.1)-Is there any correlation between Alcohol rate and life expectancy`**

# %%
# correlation between Alcohol rate and life expectancy using pandas
df[["life_expectancy", "alcohol"]].corr()
# Out:
#                  life_expectancy   alcohol
# life_expectancy         1.000000  0.397158
# alcohol                 0.397158  1.000000

# %%
# Set the figure size
plt.figure(figsize=(6, 3))

#Creat the scatter plot
sns.scatterplot(df, x="alcohol", y="life_expectancy")

# Set labels and title
plt.xlabel("Acohol",color="red")
plt.ylabel("Life Expectancy",color="red")
plt.title("Correlation between Alcohol rate and life expectancy",color="red")

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# **`(4.2)- What is the country that has the highest  Alcohol consumption?`**

# %%
# What is the country that has the highest  Alcohol consumption?
df[df["alcohol"] == df["alcohol"].max()]
# Out:
#      country  year      status  life_expectancy  adult_mortality
# 874  Estonia  2007  Developing             73.0            189.0  \
#
#      infant_deaths  alcohol  percentage_expenditure  hepatitis_b  measles
# 874            0.0    17.87                   11.48         95.0      1.0  \
#
#      ...  polio  total_expenditure  diphtheria  hiv/aids        gdp
# 874  ...   95.0               5.16        95.0       0.1  16586.452  \
#
#      population  thinness__1-19_years  thinness_5-9_years
# 874     13468.0                   2.0                 2.1  \
#
#      income_composition_of_resources  schooling
# 874                            0.829       16.0
#
# [1 rows x 22 columns]

# %%
# Correlation between Alcohol rate and life expectancy In the country with the highest alcohol consumption rate
df[df["country"] == "Estonia"][["life_expectancy", "alcohol"]].corr()
# Out:
#                  life_expectancy   alcohol
# life_expectancy         1.000000 -0.788305
# alcohol                -0.788305  1.000000

# %%
# Set the figure size
plt.figure(figsize=(6, 3))

# Create the line plot
sns.lineplot(
    df[df["country"] == "Estonia"],
    x="alcohol",
    y="life_expectancy",
    marker="o",
    color="red",
)

# Set labels and title
plt.xlabel("alcohol", color="red")
plt.ylabel("life_expectancy", color="red")
plt.title(
    "# Correlation between Alcohol rate and life expectancy In the country with the highest alcohol consumption rate",
    color="red",
)

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# **`(4.2)- What is the country that has the lowest  Alcohol consumption?`**

# %%
# What is the country that has the lowest  Alcohol consumption?
df[df["alcohol"] == df["alcohol"].min()]
# Out:
#           country  year      status  life_expectancy  adult_mortality
# 0     Afghanistan  2015  Developing             65.0            263.0  \
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2829   Uzbekistan  2012  Developing             68.8            184.0
# 2843      Vanuatu  2014  Developing             71.7            134.0
# 2844      Vanuatu  2013  Developing             71.6            135.0
# 2845      Vanuatu  2012  Developing             71.4            138.0
# 2907       Zambia  2014  Developing             61.1            314.0
#
#       infant_deaths  alcohol  percentage_expenditure  hepatitis_b    measles
# ...

# %%
# What is the country that has the lowest  Alcohol consumption in most of the years (chooses first five)?
df[df["alcohol"] == df["alcohol"].min()]["country"].value_counts().head().reset_index()
# Out:
#        country  count
# 0   Bangladesh     15
# 1  Afghanistan     11
# 2   Mauritania     11
# 3   Montenegro      8
# 4      Estonia      6

# %%
# New data set include the country that has the lowest  Alcohol consumption in most of the years
lowest_alcohol = df[
    df.country.isin(
        df[df["alcohol"] == df["alcohol"].min()]["country"]
        .value_counts()
        .head()
        .reset_index()["country"]
        .tolist()
    )
]
lowest_alcohol
# Out:
#           country  year      status  life_expectancy  adult_mortality
# 0     Afghanistan  2015  Developing             65.0            263.0  \
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 1743   Montenegro  2004  Developing             73.5            134.0
# 1744   Montenegro  2003  Developing             73.5            134.0
# 1745   Montenegro  2002  Developing             73.4            136.0
# 1746   Montenegro  2001  Developing             73.3            136.0
# 1747   Montenegro  2000  Developing             73.0            144.0
#
#       infant_deaths  alcohol  percentage_expenditure  hepatitis_b    measles
# ...

# %% [markdown]
# **`(4.3)- How does the Life Expectancy vary by country and year in the country that has the lowest  Alcohol consumption`**

# %%
# Set the figure size
plt.figure(figsize=(10, 5))

# Create the line plot
sns.lineplot(data=lowest_alcohol, x="year", y="life_expectancy", hue="country")

# Set labels and title
plt.xlabel("Year", color="red")
plt.ylabel("Life Expectancy", color="red")
plt.title(
    "How does the Life Expectancy vary by country and year in the country that has the lowest  Alcohol consumption",
    color="red",
)

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# **`(4.4)- How does the Life Expectancy vary by country and schooling in the country that has the lowest  Alcohol consumption`**

# %%
# Set the figure size
plt.figure(figsize=(10, 5))

# Create the line plot
sns.lineplot(data=lowest_alcohol, x="schooling", y="life_expectancy", hue="country")

# Set labels and title
plt.xlabel("Schooling", color="red")
plt.ylabel("Life Expectancy", color="red")
plt.title(
    "How does the Life Expectancy vary by country and Schooling in the country that has the lowest  Alcohol consumption",
    color="red",
)

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# **`(4.5)- How does the Life Expectancy vary by country and percentage_expenditure in the country that has the lowest  Alcohol consumption`**

# %%
# Set the figure size
plt.figure(figsize=(10, 5))

# Create the line plot
sns.scatterplot(
    lowest_alcohol,
    x="percentage_expenditure",
    y="life_expectancy",
    hue="country",
    legend=False,
)
sns.lineplot(
    lowest_alcohol, x="percentage_expenditure", y="life_expectancy", hue="country"
)

# Set labels and title
plt.xlabel("percentage_expenditure", color="red")
plt.ylabel("Life Expectancy", color="red")
plt.title(
    "How does the Life Expectancy vary by country and percentage expenditure in the country that has the lowest  Alcohol consumption",
    color="red",
)

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# **`(4.6)- What is the trend of alcohol consumption over the schooling`**

# %%
# Set the figure size
plt.figure(figsize=(10, 4))

# Calculate the mean of the "alcohol" column
alcohol_mean = df.groupby("schooling")["alcohol"].mean()

# Line plot and bar plot
plt.plot(alcohol_mean.index, alcohol_mean.values,marker='o',color='red',markersize=5)
plt.bar(alcohol_mean.index, alcohol_mean.values)

# Set labels and title
plt.xlabel("schooling",color="red")
plt.ylabel("Alcohol",color="red")
plt.title("Trend of alcohol consumption over the schooling",color="green")

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# # `5. Is there a relationship between healthcare expenditure(percentage_expenditure && total_expenditure ) and life expectancy?`

# %%
# Calculate the correlation coefficient between life expectancy and percentage_expenditure
correlation = df["percentage_expenditure"].corr(df["life_expectancy"])    ## print correlation on the Visualization

# Set the figure size
plt.figure(figsize=(6, 3))

# Visualize the relationship using a scatter plot
sns.scatterplot(data=df, x="percentage_expenditure", y="life_expectancy")

# Set labels and title
plt.title(f"Correlation is ({correlation:.2f})", color="g")
plt.xlabel("percentage_expenditure", color="red")
plt.ylabel("life_expectancy", color="red")

# Display the plot
plt.show()

# %%
# Calculate the correlation coefficient between life expectancy and ( total_expenditure )
correlation = df["total_expenditure"].corr(df["life_expectancy"])    ## print correlation on the Visualization

# Set the figure size
plt.figure(figsize=(6, 3))

# Visualize the relationship using a scatter plot
sns.scatterplot(data=df, x="total_expenditure", y="life_expectancy")

# Set labels and title
plt.title(f"Correlation is ({correlation:.2f})", color="g")
plt.xlabel("total_expenditure", color="red")
plt.ylabel("life_expectancy", color="red")

## Grid
sns.set_theme(style="whitegrid")

# Display the plot
plt.show()

# %% [markdown]
# **`5-1`Is there a relationship between healthcare expenditure(c && total_expenditure ) and life expectancy?`in Countries with the highest life expectancy`**

# %%
# Calculate the Countries with the highest life expectancy
highest_countries = df[
    df["life_expectancy"] == df["life_expectancy"].max()
].country.values.tolist()

# New dataset include the Countries with the highest life expectancy

df_highest = df[df["country"].isin(highest_countries)]

# Calculate the correlation coefficient between life expectancy and total_expenditure
correlation = df_highest["total_expenditure"].corr(df_highest["life_expectancy"])  ## print correlation on the Visualization


# Visualize the relationship using a line plot
sns.lineplot(data=df_highest, x="total_expenditure", y="life_expectancy", hue="country" )

# Set labels and title
plt.title(f"Correlation is ({correlation:.2f})", color="g")
plt.xlabel("total_expenditure", color="red")
plt.ylabel("life_expectancy", color="red")

# place legend in upper left of plot
plt.legend(loc="lower right", fontsize=8)

## Grid
sns.set_theme(style="whitegrid")

# Display the plot
plt.show()

# %%
# Calculate the correlation coefficient between life expectancy and  percentage_expenditure
correlation = df_highest["percentage_expenditure"].corr(df_highest["life_expectancy"])    ## print correlation on the Visualization


# Visualize the relationship using a line plot
sns.lineplot(data=df_highest, x="percentage_expenditure", y="life_expectancy",hue='country')

# Set labels and title
plt.title(f"Correlation is ({correlation:.2f})", color="g")
plt.xlabel("percentage_expenditure", color="red")
plt.ylabel("life_expectancy", color="red")

#place legend in upper left of plot
plt.legend(loc='upper left',fontsize=8)

# Display the plot
plt.show()

# %% [markdown]
# # `6. How does the presence of hepatitis B vaccination impact life expectancy?`

# %%
# Calculate the correlation coefficient between life expectancy and hepatitis B
correlation = df["hepatitis_b"].corr(df["life_expectancy"])    ## print correlation on the Visualization

# Set the figure size
plt.figure(figsize=(6, 3))

# Visualize the relationship using a scatter plot
sns.scatterplot(data=df, x="hepatitis_b", y="life_expectancy")

# Set labels and title
plt.title(f"Correlation is ({correlation:.2f})", color="g")
plt.xlabel("hepatitis_b", color="red")
plt.ylabel("life_expectancy", color="red")

# Display the plot
plt.show()

# %% [markdown]
# # `6-1 Is there a relationship between hepatitis_b and life expectancy?in Countries with the ( highest && lowest ) life expectancy`

# %%
# Calculate the Countries with the lowest life expectancy
lowest_countries = df[df["life_expectancy"] == df["life_expectancy"].min()].country.values.tolist()

# New dataset include the Countries with the highest life expectancy

df_lowest = df[df["country"].isin(lowest_countries)]

# Calculate the correlation coefficient between life expectancy and total_expenditure
correlation = df_lowest["hepatitis_b"].corr(df_lowest["life_expectancy"])  ## print correlation on the Visualization


# Visualize the relationship using a line plot
sns.lineplot(data=df_lowest, x="hepatitis_b", y="life_expectancy", hue="country" )

# Set labels and title
plt.title(f"Correlation is ({correlation:.2f})", color="g")
plt.xlabel("hepatitis_b", color="red")
plt.ylabel("life_expectancy", color="red")

# place legend in upper left of plot
plt.legend(loc="lower right", fontsize=8)

## Grid
sns.set_theme(style="whitegrid")

# Display the plot
plt.show()

# %%
# Calculate the correlation coefficient between life expectancy and total_expenditure
correlation = df_highest["hepatitis_b"].corr(df_highest["life_expectancy"]) ## print correlation on the Visualization

# Set the figure size
plt.figure(figsize=(10, 6))

# Visualize the relationship using a line plot
sns.lineplot(data=df_highest, x="hepatitis_b", y="life_expectancy", hue="country")

# Set labels and title
plt.title(f"Correlation is ({correlation:.2f})", color="g")
plt.xlabel("hepatitis_b", color="red")
plt.ylabel("life_expectancy", color="red")

# place legend in upper left of plot
plt.legend(loc="upper left", fontsize=8)

## Grid
sns.set_theme(style="whitegrid")

# Display the plot
plt.show()

# %% [markdown]
# # `How does the income composition of resources affect life expectancy?`

# %%
# Calculate the correlation coefficient between life expectancy and hepatitis B
correlation = df["income_composition_of_resources"].corr(df["life_expectancy"])    ## print correlation on the Visualization

# Set the figure size
plt.figure(figsize=(6, 3))

# Visualize the relationship using a scatter plot
sns.scatterplot(data=df, x="income_composition_of_resources", y="life_expectancy")

# Set labels and title
plt.title(f"Correlation is ({correlation:.2f})", color="g")
plt.xlabel("income_composition_of_resources", color="red")
plt.ylabel("life_expectancy", color="red")

# Display the plot
plt.show()

# %% [markdown]
# # `How does the level of schooling impact life expectancy?`

# %%
# Calculate the correlation coefficient between life expectancy and hepatitis B
correlation = df["schooling"].corr(df["life_expectancy"])## print correlation on the Visualization

# Set the figure size
plt.figure(figsize=(10, 3))

# Visualize the relationship using a scatter plot
sns.barplot(data=df, x="schooling", y="life_expectancy")

# Set labels and title
plt.title(f"Correlation is ({correlation:.2f})", color="g")
plt.xlabel("schooling", color="red")
plt.ylabel("life_expectancy", color="red")

# Display the plot
plt.show()

# %%
17. How does the income composition of resources affect life expectancy?
18. How does the level of schooling impact life expectancy?

# %%
sns.heatmap(df.select_dtypes(exclude="object").corr())
# Out:
# <Axes: >
